# %%
import pandas as pd
import numpy as np
import math

# %%
pax = pd.read_csv('data/pax_all_agreements_data.csv')
wep = pd.read_csv('data/world_economics_politics.csv', encoding = 'UTF-8')
# Out:
# /Users/yuhaozhang/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (22,86,428,472,671,681) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pax.head()
# Out:
#            Con       Contp   PP                                        PPName  \
# 0  Afghanistan  Government  2.0  Afghanistan: 2000s Post-intervention process
# 1  Afghanistan  Government  2.0  Afghanistan: 2000s Post-intervention process
# 2  Afghanistan  Government  2.0  Afghanistan: 2000s Post-intervention process
# 3  Afghanistan  Government  2.0  Afghanistan: 2000s Post-intervention process
# 4  Afghanistan  Government  2.0  Afghanistan: 2000s Post-intervention process
#
#                   Reg  AgtId  \
# 0  Europe and Eurasia   1739
# 1  Europe and Eurasia   1923
# 2  Europe and Eurasia    864
# 3  Europe and Eurasia    848
# 4  Europe and Eurasia    849
#
#                                                  Agt         Dat  \
# 0  Agreement between the Islamic Republic of Afgh...  2016-09-22
# 1  Agreement between the two campaign teams regar...  2014-09-21
# 2  Tokyo Declaration Partnership for Self-Relianc...  2012-07-08
# 3  Conclusions of the Conference on Afghanistan a...  2011-12-05
# 4  Istanbul Process on Regional Security and Coop...  2011-11-02
#
#                      Status  Lgt  ...  TjRep TjRSym TjRMa TjNR ImUN ImOth  \
# 0  Multiparty signed/agreed    4  ...      0      0     0    0    0     0
# 1  Multiparty signed/agreed    4  ...      0      0     0    0    1     1
# 2  Multiparty signed/agreed   14  ...      0      0     0    1    0     0
# 3  Multiparty signed/agreed    7  ...      0      0     0    1    1     0
# 4  Multiparty signed/agreed   10  ...      0      0     0    1    0     0
#
#   ImRef ImPK ImE  ImSrc
# 0     0    0   1      1
# 1     0    0   0      1
# 2     0    0   1      1
# 3     0    0   0      1
# 4     0    0   0      1
#
# [5 rows x 266 columns]

# %% [markdown]
# Country codes `gwno` in `wep` can be used to reference `Loc1GWNO` and `Loc2GWNO` in `pax`.

# %%
pax_afghanistan = pax[pax['Loc1GWNO'] == 700]
wep_afghanistan = wep[wep['gwno'] == 700]
wep_afghanistan[['country', 'year', 'gdp_WDI', 'gdppc_WDI_PW', 'growth_WDI', 'life_exp_WDI', 'govexp_edu_WDI', 'pop0_14_WDI', 'poleff_SFI', 'deaths_bt_WDI']]
# Out:
#           country  year       gdp_WDI  gdppc_WDI_PW  growth_WDI  life_exp_WDI  \
# 4497  Afghanistan  1989           NaN           NaN         NaN     49.031122
# 4498  Afghanistan  1990           NaN           NaN         NaN     49.861049
# 4499  Afghanistan  1991           NaN           NaN         NaN     50.640976
# 4500  Afghanistan  1992           NaN           NaN         NaN     51.362927
# 4501  Afghanistan  1993           NaN           NaN         NaN     52.021878
# 4502  Afghanistan  1994           NaN           NaN         NaN     52.614341
# 4503  Afghanistan  1995           NaN           NaN         NaN     53.139390
# 4504  Afghanistan  1996           NaN           NaN         NaN     53.602049
# 4505  Afghanistan  1997           NaN           NaN         NaN     54.017829
# 4506  Afghanistan  1998           NaN           NaN         NaN     54.402732
# 4507  Afghanistan  1999           NaN           NaN         NaN           NaN
# 4508  Afghanistan  2000           NaN           NaN         NaN     55.125878
# 4509  Afghanistan  2001           NaN           NaN         NaN     55.487536
# 4510  Afghanistan  2002  8.013233e+09    372.932641         NaN     55.857195
# 4511  Afghanistan  2003  8.689884e+09    386.090617    8.444163     56.235293
# 4512  Afghanistan  2004  8.781610e+09    373.687924    1.055556     56.626317
# 4513  Afghanistan  2005  9.762979e+09    400.122936   11.175270     57.027244
# 4514  Afghanistan  2006  1.030523e+10    409.203687    5.554138     57.432561
# 4515  Afghanistan  2007  1.172119e+10    452.948223   13.740205     57.833829
# 4516  Afghanistan  2008  1.214448e+10    457.785873    3.611368     58.225024
# 4517  Afghanistan  2009  1.469733e+10    540.198285   21.020649     58.603683
# 4518  Afghanistan  2010  1.593680e+10    569.940728    8.433290     58.970829
# 4519  Afghanistan  2011  1.691113e+10    587.005047    6.113685     59.327951
# 4520  Afghanistan  2012  1.935220e+10    651.001852   14.434741     59.679610
# 4521  Afghanistan  2013  1.973134e+10    643.081146    1.959123     60.028268
# 4522  Afghanistan  2014  1.999032e+10    632.054805    1.312531     60.374463
# 4523  Afghanistan  2015  2.015838e+10    619.751311    0.840719     60.717171
# 4524  Afghanistan  2016           NaN           NaN         NaN           NaN
# 4525  Afghanistan  2017           NaN           NaN         NaN           NaN
#
#       govexp_edu_WDI  pop0_14_WDI  poleff_SFI  deaths_bt_WDI
# 4497             NaN    47.712203         NaN         5174.0
# 4498             NaN    48.065170         NaN         1478.0
# 4499             NaN    48.029450         NaN         3302.0
# 4500             NaN    47.980565         NaN         4276.0
# 4501             NaN    47.960504         NaN         4071.0
# 4502             NaN    47.926086         NaN         8937.0
# 4503             NaN    47.797189         3.0         5499.0
# 4504             NaN    47.988880         2.0         3177.0
# 4505             NaN    48.186511         2.0         6396.0
# 4506             NaN    48.343882         2.0         6256.0
# 4507             NaN          NaN         2.0            NaN
# 4508             NaN    48.563639         2.0         5235.0
# 4509             NaN    48.506061         2.0         5148.0
# 4510             NaN    48.347456         2.0          908.0
# 4511             NaN    48.131670         2.0          687.0
# 4512             NaN    47.881433         2.0          715.0
# 4513             NaN    47.592499         2.0         1595.0
# 4514             NaN    47.696334         2.0         4750.0
# 4515             NaN    47.786807         2.0         6890.0
# 4516             NaN    47.825228         2.0         5552.0
# 4517             NaN    47.766678         2.0         6341.0
# 4518         3.46196    47.589344         2.0         6864.0
# 4519         3.43785    47.100418         2.0         7405.0
# 4520         2.52441    46.449243         2.0         7719.0
# 4521         3.47171    45.685257         2.0         8056.0
# 4522         3.77759    44.870996         2.0         1228.0
# 4523         3.37581    44.041949         2.0         1727.0
# 4524             NaN          NaN         NaN            NaN
# 4525             NaN          NaN         NaN            NaN

# %%
pax_us = pax[pax['Loc1GWNO'] == 2]
wep_us = wep[wep['gwno'] == 2]
wep_us[['country', 'year', 'gdp_WDI', 'gdppc_WDI_PW', 'growth_WDI', 'life_exp_WDI', 'govexp_edu_WDI', 'pop0_14_WDI', 'poleff_SFI', 'deaths_bt_WDI']]
# Out:
#                      country  year       gdp_WDI  gdppc_WDI_PW  growth_WDI  \
# 0   United States of America  1989  8.890000e+12    36033.3302    3.680524
# 1   United States of America  1990  9.060000e+12    36312.4141    1.919370
# 2   United States of America  1991  9.060000e+12    35803.8684   -0.074085
# 3   United States of America  1992  9.380000e+12    36566.1737    3.555396
# 4   United States of America  1993  9.640000e+12    37078.0496    2.745857
# 5   United States of America  1994  1.000000e+13    38104.9724    4.037643
# 6   United States of America  1995  1.030000e+13    38677.7150    2.718976
# 7   United States of America  1996  1.070000e+13    39681.5198    3.795881
# 8   United States of America  1997  1.120000e+13    40965.8466    4.487026
# 9   United States of America  1998  1.170000e+13    42292.8912    4.449911
# 10  United States of America  1999           NaN    32677.4772         NaN
# 11  United States of America  2000  1.270000e+13    45055.8179    4.092176
# 12  United States of America  2001  1.280000e+13    45047.4872    0.975982
# 13  United States of America  2002  1.310000e+13    45428.6456    1.786128
# 14  United States of America  2003  1.340000e+13    46304.0360    2.806776
# 15  United States of America  2004  1.390000e+13    47614.2798    3.785743
# 16  United States of America  2005  1.440000e+13    48755.6160    3.345216
# 17  United States of America  2006  1.480000e+13    49575.4010    2.666626
# 18  United States of America  2007  1.510000e+13    49979.5338    1.778570
# 19  United States of America  2008  1.500000e+13    49364.6445   -0.291621
# 20  United States of America  2009  1.460000e+13    47575.6085   -2.775530
# 21  United States of America  2010  1.500000e+13    48374.0867    2.531921
# 22  United States of America  2011  1.520000e+13    48774.7830    1.601455
# 23  United States of America  2012  1.550000e+13    49481.1586    2.224031
# 24  United States of America  2013  1.580000e+13    49941.4891    1.677332
# 25  United States of America  2014  1.620000e+13    50727.7512    2.370458
# 26  United States of America  2015  1.660000e+13    51638.0652    2.596148
# 27  United States of America  2016           NaN           NaN         NaN
# 28  United States of America  2017           NaN           NaN         NaN
#
#     life_exp_WDI  govexp_edu_WDI  pop0_14_WDI  poleff_SFI  deaths_bt_WDI
# 0      75.017073         4.79609    21.600248         NaN            NaN
# 1      75.214634         4.81642    21.599222         NaN            NaN
# 2      75.365854         4.89907    21.687110         NaN            NaN
# 3      75.617073             NaN    21.764509         NaN            NaN
# 4      75.419512             NaN    21.809988         NaN            NaN
# 5      75.619512         4.87409    21.804637         NaN            NaN
# 6      75.621951         4.94153    21.747612         0.0            NaN
# 7      76.026829             NaN    21.739666         0.0            NaN
# 8      76.429268             NaN    21.657913         0.0            NaN
# 9      76.580488         4.81543    21.529777         0.0            NaN
# 10           NaN             NaN          NaN         0.0            NaN
# 11     76.636585             NaN    21.258516         0.0            NaN
# 12     76.836585         5.45786    21.084114         0.0          233.0
# 13     76.936585         5.40620    20.947899         0.0            NaN
# 14     77.036585         5.56551    20.816347         0.0            NaN
# 15     77.487805         5.30923    20.647027         0.0            NaN
# 16     77.487805         5.07365    20.428193         0.0            NaN
# 17     77.687805         5.38881    20.367775         0.0            NaN
# 18     77.987805         5.24649    20.242371         0.0            NaN
# 19     78.039024         5.30354    20.077181         0.0            NaN
# 20     78.390244         5.24958    19.909238         0.0            NaN
# 21     78.541463         5.42001    19.753453         0.0            NaN
# 22     78.641463         5.22390    19.555566         0.0            NaN
# 23     78.741463         5.19486    19.358003         0.0            NaN
# 24     78.741463         4.94379    19.189896         0.0            NaN
# 25     78.741463             NaN    19.057379         0.0            NaN
# 26     78.741463             NaN    18.950345         0.0            NaN
# 27           NaN             NaN          NaN         NaN            NaN
# 28           NaN             NaN          NaN         NaN            NaN

# %%
count = 0
for gwno_code in wep['gwno'].unique():
    data_size = pax[(pax['Loc1GWNO'] == gwno_code) | (pax['Loc2GWNO'] == gwno_code)].shape[0]
    if data_size > 0:
        count = count + 1
print(count / np.size(wep['gwno'].unique()))
# Out:
# 0.45365853658536587

# %% [markdown]
# About half of the countries recorded by world bank were mentioned in the PA-X database

# %%
country_with_care = set()
for i, v in pax[pax['GeWom'] == 1].iterrows():
    loc1 = v['Loc1GWNO']
    loc2 = v['Loc2GWNO']

    if not pd.isnull(loc1):
        country_with_care.add(loc1)
        #print('loc1: {}'.format(loc1))
        
    if not pd.isnull(loc2):
        country_with_care.add(loc2)
        #print('loc2: {}'.format(loc2))

print(country_with_care)
# Out:
# {770.0, 771.0, 516.0, 645.0, 517.0, 775.0, 520.0, 652.0, 780.0, 910.0, 790.0, 666.0, 540.0, 678.0, 552.0, 811.0, 432.0, 560.0, 692.0, 437.0, 570.0, 700.0, 702.0, 450.0, 451.0, 580.0, 581.0, 70.0, 200.0, 840.0, 205.0, 461.0, 850.0, 344.0, 90.0, 346.0, 92.0, 347.0, 93.0, 475.0, 482.0, 483.0, 100.0, 615.0, 616.0, 490.0, 235.0, 620.0, 365.0, 750.0, 625.0, 626.0, 372.0, 501.0, 500.0}

# %%
To see whether

# %%
(pax[pd.isnull(pax['Loc1GWNO'])].iloc[0])
# Out:
# Con       Angola/Burundi/Central African Republic/Democr...
# Contp                                            Government
# PP                                                        6
# PPName                African Great Lakes: Regional Process
# Reg                                      Africa (excl MENA)
#                                 ...
# ImOth                                                     0
# ImRef                                                     0
# ImPK                                                      0
# ImE                                                       1
# ImSrc                                                     1
# Name: 39, Length: 266, dtype: object

# %%
wep[wep['gwno'] == 700][['year', 'wecon_CR', 'wopol_CR']]
# Out:
#       year  wecon_CR  wopol_CR
# 4497  1989       0.0       1.0
# 4498  1990       0.0       1.0
# 4499  1991       0.0       0.0
# 4500  1992     -77.0     -77.0
# 4501  1993     -77.0     -77.0
# 4502  1994     -77.0     -77.0
# 4503  1995     -77.0     -77.0
# 4504  1996       0.0       0.0
# 4505  1997       0.0       0.0
# 4506  1998       0.0       0.0
# 4507  1999       0.0       0.0
# 4508  2000       0.0       0.0
# 4509  2001       0.0       0.0
# 4510  2002       0.0       0.0
# 4511  2003     -66.0     -66.0
# 4512  2004     -66.0     -66.0
# 4513  2005       0.0       2.0
# 4514  2006       0.0       2.0
# 4515  2007       0.0       3.0
# 4516  2008       0.0       2.0
# 4517  2009       0.0       2.0
# 4518  2010       0.0       2.0
# 4519  2011       0.0       2.0
# 4520  2012       NaN       NaN
# 4521  2013       NaN       NaN
# 4522  2014       NaN       NaN
# 4523  2015       NaN       NaN
# 4524  2016       NaN       NaN
# 4525  2017       NaN       NaN

# %%
pax[(pax['Con'] == 'Afghanistan') & pax['GeWom'] == 1]
# Out:
#             Con       Contp   PP  \
# 0   Afghanistan  Government  2.0
# 1   Afghanistan  Government  2.0
# 2   Afghanistan  Government  2.0
# 3   Afghanistan  Government  2.0
# 4   Afghanistan  Government  2.0
# 5   Afghanistan  Government  2.0
# 6   Afghanistan  Government  2.0
# 7   Afghanistan  Government  2.0
# 8   Afghanistan  Government  2.0
# 10  Afghanistan  Government  2.0
# 12  Afghanistan  Government  2.0
# 13  Afghanistan  Government  2.0
# 15  Afghanistan  Government  2.0
# 16  Afghanistan  Government  2.0
# 17  Afghanistan  Government  2.0
#
#                                           PPName                 Reg  AgtId  \
# 0   Afghanistan: 2000s Post-intervention process  Europe and Eurasia   1739
# 1   Afghanistan: 2000s Post-intervention process  Europe and Eurasia   1923
# 2   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    864
# 3   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    848
# 4   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    849
# 5   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    709
# 6   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    708
# 7   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    707
# 8   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    706
# 10  Afghanistan: 2000s Post-intervention process  Europe and Eurasia    705
# 12  Afghanistan: 2000s Post-intervention process  Europe and Eurasia   1061
# 13  Afghanistan: 2000s Post-intervention process  Europe and Eurasia   1054
# 15  Afghanistan: 2000s Post-intervention process  Europe and Eurasia    908
# 16  Afghanistan: 2000s Post-intervention process  Europe and Eurasia    272
# 17  Afghanistan: 2000s Post-intervention process  Europe and Eurasia    553
#
#                                                   Agt         Dat  \
# 0   Agreement between the Islamic Republic of Afgh...  2016-09-22
# 1   Agreement between the two campaign teams regar...  2014-09-21
# 2   Tokyo Declaration Partnership for Self-Relianc...  2012-07-08
# 3   Conclusions of the Conference on Afghanistan a...  2011-12-05
# 4   Istanbul Process on Regional Security and Coop...  2011-11-02
# 5   Renewed Commitment by the Afghan Government to...  2010-07-22
# 6   The Resolution Adopted at the Conclusion of th...  2010-06-06
# 7   Communiqué of the Conference on Afghan Leaders...  2010-01-28
# 8   Statement of the International Conference on A...  2009-03-31
# 10  Declaration of the International Conference in...  2008-06-12
# 12  Afghanistan Compact Building on Success (Londo...  2006-02-01
# 13             Berlin Declaration (Berlin Conference)  2004-04-01
# 15  Communiqué of the International Conference on ...  2002-01-22
# 16  Agreement on Provisional Arrangements in Afgha...  2001-12-05
# 17  Tashkent Declaration on Fundamental Principles...  1999-07-19
#
#                       Status  Lgt  ...  TjRep TjRSym TjRMa TjNR ImUN ImOth  \
# 0   Multiparty signed/agreed    4  ...      0      0     0    0    0     0
# 1   Multiparty signed/agreed    4  ...      0      0     0    0    1     1
# 2   Multiparty signed/agreed   14  ...      0      0     0    1    0     0
# 3   Multiparty signed/agreed    7  ...      0      0     0    1    1     0
# 4   Multiparty signed/agreed   10  ...      0      0     0    1    0     0
# 5   Multiparty signed/agreed    9  ...      0      0     0    1    0     0
# 6   Multiparty signed/agreed    4  ...      0      0     0    1    0     0
# 7   Multiparty signed/agreed    7  ...      0      0     0    1    0     0
# 8   Multiparty signed/agreed    4  ...      0      0     0    0    0     0
# 10  Multiparty signed/agreed    3  ...      0      0     0    0    1     0
# 12  Multiparty signed/agreed   17  ...      0      0     0    1    1     1
# 13  Multiparty signed/agreed    3  ...      0      0     0    0    0     0
# 15  Multiparty signed/agreed    5  ...      0      0     0    1    1     1
# 16  Multiparty signed/agreed   13  ...      0      0     0    1    1     0
# 17  Multiparty signed/agreed    5  ...      0      0     0    0    1     0
#
#    ImRef ImPK ImE  ImSrc
# 0      0    0   1      1
# 1      0    0   0      1
# 2      0    0   1      1
# 3      0    0   0      1
# 4      0    0   0      1
# 5      0    1   1      1
# 6      0    0   0      1
# 7      0    1   0      1
# 8      0    1   0      1
# 10     0    0   0      1
# 12     0    1   1      1
# 13     0    1   0      1
# 15     0    0   0      1
# 16     0    1   0      1
# 17     0    0   0      1
#
# [15 rows x 266 columns]

# %%
pax[(pax['Con'] == 'Afghanistan') & pax['GeWom'] == 1]
# Out:
#             Con       Contp   PP  \
# 0   Afghanistan  Government  2.0
# 1   Afghanistan  Government  2.0
# 2   Afghanistan  Government  2.0
# 3   Afghanistan  Government  2.0
# 4   Afghanistan  Government  2.0
# 5   Afghanistan  Government  2.0
# 6   Afghanistan  Government  2.0
# 7   Afghanistan  Government  2.0
# 8   Afghanistan  Government  2.0
# 10  Afghanistan  Government  2.0
# 12  Afghanistan  Government  2.0
# 13  Afghanistan  Government  2.0
# 15  Afghanistan  Government  2.0
# 16  Afghanistan  Government  2.0
# 17  Afghanistan  Government  2.0
#
#                                           PPName                 Reg  AgtId  \
# 0   Afghanistan: 2000s Post-intervention process  Europe and Eurasia   1739
# 1   Afghanistan: 2000s Post-intervention process  Europe and Eurasia   1923
# 2   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    864
# 3   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    848
# 4   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    849
# 5   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    709
# 6   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    708
# 7   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    707
# 8   Afghanistan: 2000s Post-intervention process  Europe and Eurasia    706
# 10  Afghanistan: 2000s Post-intervention process  Europe and Eurasia    705
# 12  Afghanistan: 2000s Post-intervention process  Europe and Eurasia   1061
# 13  Afghanistan: 2000s Post-intervention process  Europe and Eurasia   1054
# 15  Afghanistan: 2000s Post-intervention process  Europe and Eurasia    908
# 16  Afghanistan: 2000s Post-intervention process  Europe and Eurasia    272
# 17  Afghanistan: 2000s Post-intervention process  Europe and Eurasia    553
#
#                                                   Agt         Dat  \
# 0   Agreement between the Islamic Republic of Afgh...  2016-09-22
# 1   Agreement between the two campaign teams regar...  2014-09-21
# 2   Tokyo Declaration Partnership for Self-Relianc...  2012-07-08
# 3   Conclusions of the Conference on Afghanistan a...  2011-12-05
# 4   Istanbul Process on Regional Security and Coop...  2011-11-02
# 5   Renewed Commitment by the Afghan Government to...  2010-07-22
# 6   The Resolution Adopted at the Conclusion of th...  2010-06-06
# 7   Communiqué of the Conference on Afghan Leaders...  2010-01-28
# 8   Statement of the International Conference on A...  2009-03-31
# 10  Declaration of the International Conference in...  2008-06-12
# 12  Afghanistan Compact Building on Success (Londo...  2006-02-01
# 13             Berlin Declaration (Berlin Conference)  2004-04-01
# 15  Communiqué of the International Conference on ...  2002-01-22
# 16  Agreement on Provisional Arrangements in Afgha...  2001-12-05
# 17  Tashkent Declaration on Fundamental Principles...  1999-07-19
#
#                       Status  Lgt  ...  TjRep TjRSym TjRMa TjNR ImUN ImOth  \
# 0   Multiparty signed/agreed    4  ...      0      0     0    0    0     0
# 1   Multiparty signed/agreed    4  ...      0      0     0    0    1     1
# 2   Multiparty signed/agreed   14  ...      0      0     0    1    0     0
# 3   Multiparty signed/agreed    7  ...      0      0     0    1    1     0
# 4   Multiparty signed/agreed   10  ...      0      0     0    1    0     0
# 5   Multiparty signed/agreed    9  ...      0      0     0    1    0     0
# 6   Multiparty signed/agreed    4  ...      0      0     0    1    0     0
# 7   Multiparty signed/agreed    7  ...      0      0     0    1    0     0
# 8   Multiparty signed/agreed    4  ...      0      0     0    0    0     0
# 10  Multiparty signed/agreed    3  ...      0      0     0    0    1     0
# 12  Multiparty signed/agreed   17  ...      0      0     0    1    1     1
# 13  Multiparty signed/agreed    3  ...      0      0     0    0    0     0
# 15  Multiparty signed/agreed    5  ...      0      0     0    1    1     1
# 16  Multiparty signed/agreed   13  ...      0      0     0    1    1     0
# 17  Multiparty signed/agreed    5  ...      0      0     0    0    1     0
#
#    ImRef ImPK ImE  ImSrc
# 0      0    0   1      1
# 1      0    0   0      1
# 2      0    0   1      1
# 3      0    0   0      1
# 4      0    0   0      1
# 5      0    1   1      1
# 6      0    0   0      1
# 7      0    1   0      1
# 8      0    1   0      1
# 10     0    0   0      1
# 12     0    1   1      1
# 13     0    1   0      1
# 15     0    0   0      1
# 16     0    1   0      1
# 17     0    0   0      1
#
# [15 rows x 266 columns]

# %%
# Out:
#           country  year  gwno  ccode  ifscode  ifs gwabbrev    ers_TR  mi_TR  \
# 4497  Afghanistan  1989   700  700.0    512.0  AFG      AFG  1.000000    NaN
# 4498  Afghanistan  1990   700  700.0    512.0  AFG      AFG  1.000000    NaN
# 4499  Afghanistan  1991   700  700.0    512.0  AFG      AFG  1.000000    NaN
# 4500  Afghanistan  1992   700  700.0    512.0  AFG      AFG  1.000000    NaN
# 4501  Afghanistan  1993   700  700.0    512.0  AFG      AFG  1.000000    NaN
# 4502  Afghanistan  1994   700  700.0    512.0  AFG      AFG  1.000000    NaN
# 4503  Afghanistan  1995   700  700.0    512.0  AFG      AFG  1.000000    NaN
# 4504  Afghanistan  1996   700  700.0    512.0  AFG      AFG  1.000000    NaN
# 4505  Afghanistan  1997   700  700.0    512.0  AFG      AFG  1.000000    NaN
# 4506  Afghanistan  1998   700  700.0    512.0  AFG      AFG  1.000000    NaN
# 4507  Afghanistan  1999   700  700.0    512.0  AFG      AFG       NaN    NaN
# 4508  Afghanistan  2000   700  700.0    512.0  AFG      AFG       NaN    NaN
# 4509  Afghanistan  2001   700  700.0    512.0  AFG      AFG       NaN    NaN
# 4510  Afghanistan  2002   700  700.0    512.0  AFG      AFG  0.062848    NaN
# 4511  Afghanistan  2003   700  700.0    512.0  AFG      AFG  0.218015    NaN
# 4512  Afghanistan  2004   700  700.0    512.0  AFG      AFG  0.312352    NaN
# 4513  Afghanistan  2005   700  700.0    512.0  AFG      AFG  0.412669    NaN
# 4514  Afghanistan  2006   700  700.0    512.0  AFG      AFG  0.691169    NaN
# 4515  Afghanistan  2007   700  700.0    512.0  AFG      AFG  0.728969    NaN
# 4516  Afghanistan  2008   700  700.0    512.0  AFG      AFG  0.529204    NaN
# 4517  Afghanistan  2009   700  700.0    512.0  AFG      AFG  0.523133    NaN
# 4518  Afghanistan  2010   700  700.0    512.0  AFG      AFG  0.352281    NaN
# 4519  Afghanistan  2011   700  700.0    512.0  AFG      AFG  0.457508    NaN
# 4520  Afghanistan  2012   700  700.0    512.0  AFG      AFG  0.434885    NaN
# 4521  Afghanistan  2013   700  700.0    512.0  AFG      AFG  0.419871    NaN
# 4522  Afghanistan  2014   700  700.0    512.0  AFG      AFG  0.386895    NaN
# 4523  Afghanistan  2015   700  700.0    512.0  AFG      AFG       NaN    NaN
# 4524  Afghanistan  2016   700  700.0    512.0  AFG      AFG       NaN    NaN
# 4525  Afghanistan  2017   700  700.0    512.0  AFG      AFG       NaN    NaN
#
#       ka_open_TR  ...  hommicidempc_count_ODC  hommicidempc_rate_ODC  \
# 4497         0.0  ...                     NaN                    NaN
# 4498         0.0  ...                     NaN                    NaN
# 4499         0.0  ...                     NaN                    NaN
# 4500         0.0  ...                     NaN                    NaN
# 4501         0.0  ...                     NaN                    NaN
# 4502         0.0  ...                     NaN                    NaN
# 4503         NaN  ...                     NaN                    NaN
# 4504         NaN  ...                     NaN                    NaN
# 4505         NaN  ...                     NaN                    NaN
# 4506         NaN  ...                     NaN                    NaN
# 4507         NaN  ...                     NaN                    NaN
# 4508         0.0  ...                     NaN                    NaN
# 4509         NaN  ...                     NaN                    NaN
# 4510         NaN  ...                     NaN                    NaN
# 4511         NaN  ...                     NaN                    NaN
# 4512         NaN  ...                     NaN                    NaN
# 4513         NaN  ...                     NaN                    NaN
# 4514         NaN  ...                     NaN                    NaN
# 4515         NaN  ...                     NaN                    NaN
# 4516         NaN  ...                     NaN                    NaN
# 4517         NaN  ...                     NaN                    NaN
# 4518         NaN  ...                     NaN                    NaN
# 4519         NaN  ...                     NaN                    NaN
# 4520         NaN  ...                     NaN                    NaN
# 4521         NaN  ...                     NaN                    NaN
# 4522         NaN  ...                     NaN                    NaN
# 4523         NaN  ...                     NaN                    NaN
# 4524         NaN  ...                     NaN                    NaN
# 4525         NaN  ...                     NaN                    NaN
#
#       mpcity_ODC  mvtheft_count_ODC  mvtheft_rate_ODC  robbery_count_ODC  \
# 4497         NaN                NaN               NaN                NaN
# 4498         NaN                NaN               NaN                NaN
# 4499         NaN                NaN               NaN                NaN
# 4500         NaN                NaN               NaN                NaN
# 4501         NaN                NaN               NaN                NaN
# 4502         NaN                NaN               NaN                NaN
# 4503         NaN                NaN               NaN                NaN
# 4504         NaN                NaN               NaN                NaN
# 4505         NaN                NaN               NaN                NaN
# 4506         NaN                NaN               NaN                NaN
# 4507         NaN                NaN               NaN                NaN
# 4508         NaN                NaN               NaN                NaN
# 4509         NaN                NaN               NaN                NaN
# 4510         NaN                NaN               NaN                NaN
# 4511         NaN                NaN               NaN                NaN
# 4512         NaN                NaN               NaN                NaN
# 4513         NaN                NaN               NaN                NaN
# 4514         NaN                NaN               NaN                NaN
# 4515         NaN                NaN               NaN                NaN
# 4516         NaN                NaN               NaN                NaN
# 4517         NaN                NaN               NaN                NaN
# 4518         NaN                NaN               NaN                NaN
# 4519         NaN                NaN               NaN                NaN
# 4520         NaN                NaN               NaN                NaN
# 4521         NaN                NaN               NaN                NaN
# 4522         NaN                NaN               NaN                NaN
# 4523         NaN                NaN               NaN                NaN
# 4524         NaN                NaN               NaN                NaN
# 4525         NaN                NaN               NaN                NaN
#
#       robbery_rate_ODC theft_count_ODC theft_rate_ODC ptratio_seced_ES
# 4497               NaN             NaN            NaN               ..
# 4498               NaN             NaN            NaN       24.7879295
# 4499               NaN             NaN            NaN               ..
# 4500               NaN             NaN            NaN               ..
# 4501               NaN             NaN            NaN       26.6846103
# 4502               NaN             NaN            NaN       28.3657398
# 4503               NaN             NaN            NaN               ..
# 4504               NaN             NaN            NaN               ..
# 4505               NaN             NaN            NaN               ..
# 4506               NaN             NaN            NaN               ..
# 4507               NaN             NaN            NaN               ..
# 4508               NaN             NaN            NaN               ..
# 4509               NaN             NaN            NaN               ..
# 4510               NaN             NaN            NaN               ..
# 4511               NaN             NaN            NaN               ..
# 4512               NaN             NaN            NaN               ..
# 4513               NaN             NaN            NaN               ..
# 4514               NaN             NaN            NaN               ..
# 4515               NaN             NaN            NaN       31.5623607
# 4516               NaN             NaN            NaN               ..
# 4517               NaN             NaN            NaN               ..
# 4518               NaN             NaN            NaN               ..
# 4519               NaN             NaN            NaN               ..
# 4520               NaN             NaN            NaN               ..
# 4521               NaN             NaN            NaN               ..
# 4522               NaN             NaN            NaN               ..
# 4523               NaN             NaN            NaN               ..
# 4524               NaN             NaN            NaN              NaN
# 4525               NaN             NaN            NaN              NaN
#
# [29 rows x 892 columns]

# %%
def search_wep_gwno(gwno, col_names):
    return wep[wep['gwno'] == gwno][col_names]

def search_wep_country(country, col_names):
    return wep[wep['country'] == country][col_names]

def search_pax_gwno(gwno, col_names):
    return pax[(pax['Loc1GWNO'] == gwno) | (pax['Loc2GWNO'] == gwno)][col_names]

def search_pax_entity(entity, col_names):
    return pax[pax['Con'] == entity][col_names]

#search_wep_gwno(700, ['country', 'year', 'gendereq_CPIA','muspct_RCS'])
#search_wep_country('Afghanistan', ['country', 'year', 'lpc_F_1519_BL','lpc_F_25999_BL','gendereq_CPIA','muspct_RCS'])
pax[pax['GCh'] == 3].shape[0]
# Out:
# 78

# %%
search_wep_gwno(678, ['country', 'year', 'lpc_F_1519_BL','lpc_F_25999_BL','gendereq_CPIA','muspct_RCS'])
# Out:
#                              country  year  lpc_F_1519_BL  lpc_F_25999_BL  \
# 4296  Yemen (Arab Republic of Yemen)  1989            NaN             NaN
# 4297  Yemen (Arab Republic of Yemen)  1990       6.938415        0.492405
# 4298  Yemen (Arab Republic of Yemen)  1991            NaN             NaN
# 4299  Yemen (Arab Republic of Yemen)  1992            NaN             NaN
# 4300  Yemen (Arab Republic of Yemen)  1993            NaN             NaN
# 4301  Yemen (Arab Republic of Yemen)  1994            NaN             NaN
# 4302  Yemen (Arab Republic of Yemen)  1995      11.444736        0.904540
# 4303  Yemen (Arab Republic of Yemen)  1996            NaN             NaN
# 4304  Yemen (Arab Republic of Yemen)  1997            NaN             NaN
# 4305  Yemen (Arab Republic of Yemen)  1998            NaN             NaN
# 4306  Yemen (Arab Republic of Yemen)  1999            NaN             NaN
# 4307  Yemen (Arab Republic of Yemen)  2000       9.608559        1.336725
# 4308  Yemen (Arab Republic of Yemen)  2001            NaN             NaN
# 4309  Yemen (Arab Republic of Yemen)  2002            NaN             NaN
# 4310  Yemen (Arab Republic of Yemen)  2003            NaN             NaN
# 4311  Yemen (Arab Republic of Yemen)  2004            NaN             NaN
# 4312  Yemen (Arab Republic of Yemen)  2005       1.957426        2.686731
# 4313  Yemen (Arab Republic of Yemen)  2006            NaN             NaN
# 4314  Yemen (Arab Republic of Yemen)  2007            NaN             NaN
# 4315  Yemen (Arab Republic of Yemen)  2008            NaN             NaN
# 4316  Yemen (Arab Republic of Yemen)  2009            NaN             NaN
# 4317  Yemen (Arab Republic of Yemen)  2010      15.711287        3.931968
# 4318  Yemen (Arab Republic of Yemen)  2011            NaN             NaN
# 4319  Yemen (Arab Republic of Yemen)  2012            NaN             NaN
# 4320  Yemen (Arab Republic of Yemen)  2013            NaN             NaN
# 4321  Yemen (Arab Republic of Yemen)  2014            NaN             NaN
# 4322  Yemen (Arab Republic of Yemen)  2015            NaN             NaN
# 4323  Yemen (Arab Republic of Yemen)  2016            NaN             NaN
# 4324  Yemen (Arab Republic of Yemen)  2017            NaN             NaN
#
#       gendereq_CPIA  muspct_RCS
# 4296            NaN    99.82758
# 4297            NaN    99.33111
# 4298            NaN    99.30603
# 4299            NaN    99.28096
# 4300            NaN    99.25587
# 4301            NaN    99.23080
# 4302            NaN    99.20572
# 4303            NaN    99.18064
# 4304            NaN    99.15556
# 4305            NaN    99.13049
# 4306            NaN    99.10540
# 4307            NaN    99.08032
# 4308            NaN    99.08071
# 4309            NaN    99.08111
# 4310            NaN    99.08151
# 4311            NaN    99.08190
# 4312            2.0    99.08230
# 4313            2.0    99.08270
# 4314            2.0    99.08308
# 4315            2.0    99.08348
# 4316            2.0    99.08388
# 4317            2.0    99.08427
# 4318            2.0         NaN
# 4319            2.0         NaN
# 4320            2.0         NaN
# 4321            2.0         NaN
# 4322            1.0         NaN
# 4323            1.0         NaN
# 4324            NaN         NaN
